# %% [markdown]
# ### Our end goal is to predict the number of users of bike sharing system

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split


df = pd.read_csv('./Bike-Sharing-Dataset/hour.csv')
# season : season (1:winter, 2:spring, 3:summer, 4:fall)
#yr : year (0: 2011, 1:2012)
df.shape
# Out:
# (17379, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
# instant       17379 non-null int64
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
df.head(5)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Identifying if there is null values in DataFrame

# %%
df.isnull().sum()
# df.isnull().values.any()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %% [markdown]
# ### Identifying columns and rows with duplicate entries

# %%
df.duplicated().any()
# Out:
# False

# %%
df.dtypes
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %% [markdown]
# ###  Removing 'instant' column

# %%
df = df.drop(['instant'], axis=1)
df.head()
# Out:
#        dteday  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1   0     1   0        0        6           0           1
# 1  2011-01-01       1   0     1   1        0        6           0           1
# 2  2011-01-01       1   0     1   2        0        6           0           1
# 3  2011-01-01       1   0     1   3        0        6           0           1
# 4  2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ### Converting 'dteday' to datetime

# %%
df['date'] = pd.to_datetime(df['dteday']) 
df = df.drop(['dteday'], axis=1)
df.head()
# Out:
#    season  yr  mnth  hr  holiday  weekday  workingday  weathersit  temp  \
# 0       1   0     1   0        0        6           0           1  0.24
# 1       1   0     1   1        0        6           0           1  0.22
# 2       1   0     1   2        0        6           0           1  0.22
# 3       1   0     1   3        0        6           0           1  0.24
# 4       1   0     1   4        0        6           0           1  0.24
#
#     atemp   hum  windspeed  casual  registered  cnt       date
# 0  0.2879  0.81        0.0       3          13   16 2011-01-01
# 1  0.2727  0.80        0.0       8          32   40 2011-01-01
# 2  0.2727  0.80        0.0       5          27   32 2011-01-01
# 3  0.2879  0.75        0.0       3          10   13 2011-01-01
# 4  0.2879  0.75        0.0       0           1    1 2011-01-01

# %% [markdown]
# ### Moving date to the front of DataFrame

# %%
df.columns
# Out:
# Index(['season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt', 'date'],
#       dtype='object')

# %%
cols = ['date','season', 'yr', 'mnth', 'hr', 'holiday', 'weekday', 'workingday',
       'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
       'registered', 'cnt']

# %%
df = df[cols]
df.head()
# Out:
#         date  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0 2011-01-01       1   0     1   0        0        6           0           1
# 1 2011-01-01       1   0     1   1        0        6           0           1
# 2 2011-01-01       1   0     1   2        0        6           0           1
# 3 2011-01-01       1   0     1   3        0        6           0           1
# 4 2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
df.dtypes
# Out:
# date          datetime64[ns]
# season                 int64
# yr                     int64
# mnth                   int64
# hr                     int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# dtype: object

# %%
df.corr()
# Out:
#               season        yr      mnth        hr   holiday   weekday  \
# season      1.000000 -0.010742  0.830386 -0.006117 -0.009585 -0.002335
# yr         -0.010742  1.000000 -0.010473 -0.003867  0.006692 -0.004485
# mnth        0.830386 -0.010473  1.000000 -0.005772  0.018430  0.010400
# hr         -0.006117 -0.003867 -0.005772  1.000000  0.000479 -0.003498
# holiday    -0.009585  0.006692  0.018430  0.000479  1.000000 -0.102088
# weekday    -0.002335 -0.004485  0.010400 -0.003498 -0.102088  1.000000
# workingday  0.013743 -0.002196 -0.003477  0.002285 -0.252471  0.035955
# weathersit -0.014524 -0.019157  0.005400 -0.020203 -0.017036  0.003311
# temp        0.312025  0.040913  0.201691  0.137603 -0.027340 -0.001795
# atemp       0.319380  0.039222  0.208096  0.133750 -0.030973 -0.008821
# hum         0.150625 -0.083546  0.164411 -0.276498 -0.010588 -0.037158
# windspeed  -0.149773 -0.008740 -0.135386  0.137252  0.003988  0.011502
# ...

# %%
plt.figure(figsize=(9,8))
sns.heatmap(df.corr(), annot=True,cmap='BuPu', linewidth = 0.2)

# %% [markdown]
# ### Feature selection

# %%
df.head()
# Out:
#         date  season  yr  mnth  hr  holiday  weekday  workingday  weathersit  \
# 0 2011-01-01       1   0     1   0        0        6           0           1
# 1 2011-01-01       1   0     1   1        0        6           0           1
# 2 2011-01-01       1   0     1   2        0        6           0           1
# 3 2011-01-01       1   0     1   3        0        6           0           1
# 4 2011-01-01       1   0     1   4        0        6           0           1
#
#    temp   atemp   hum  windspeed  casual  registered  cnt
# 0  0.24  0.2879  0.81        0.0       3          13   16
# 1  0.22  0.2727  0.80        0.0       8          32   40
# 2  0.22  0.2727  0.80        0.0       5          27   32
# 3  0.24  0.2879  0.75        0.0       3          10   13
# 4  0.24  0.2879  0.75        0.0       0           1    1

# %%
features = ['hr', 'temp', 'casual', 'registered']
target = ['cnt']

train_df = df[:8690]
test_df = df[8690:]
# train_df.head()
# test_df.head()

# %%
lr = LinearRegression()
lr.fit(train_df[features], train_df[target])
lr.score(train_df[features], train_df[target])
# Out:
# 1.0

# %%
predicted = lr.predict(test_df[features])
print(predicted)
# Out:
# [[39.]
#  [34.]
#  [13.]
#  ...
#  [90.]
#  [61.]
#  [49.]]

# %%
mse = mean_squared_error(test_df[target], predicted)
print(mse)
rmse = np.sqrt(mse)
print(rmse)
# Out:
# 6.025735746094672e-26
# 2.454737408786258e-13
